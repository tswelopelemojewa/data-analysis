# %%
import os
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder

labEncod = LabelEncoder()

# %%
os.getcwd()
# Out:
# 'C:\\Users\\user\\Desktop\\data scence\\data'

# %%
os.chdir('C:\\Users\\user\\Desktop\\data scence\\data')

# %%
# os.getcwd()

data = pd.read_excel("mathematics.xlsx")

# %%
# fist 10 learners

data.head(10)
# Out:
#    No  Unnamed: 1  Acc No             Learner  Gender  SBA 1  SBA 2  SBA 3  \
# 0   1        1403   21078         BAPELA, Joy  Female     34     13     41
# 1   2        1410   21075  BOKABA, Gaboitsiwe  Female     25      7     27
# 2   3        1411   21074  BOKABA, Kelebogile    Male     37     18     31
# 3   4        1513   22064     BOKABA, Ofentse  Female     35     23     32
# 4   5        1343   21006    BOPAPE, Johannah  Female     37     32     42
# 5   6        1409   21068     KABINI, Boipelo  Female     37     22     35
# 6   7        1512   22063      KGAFELA, Cathy  Female     41     32     38
# 7   8        1445   21111     KGAFELA, Khutso    Male     31     12     30
# 8   9        1447   21112    KGAFELA, Oratile    Male     33     14     25
# 9  10        1348   21011        KOBE, Junior    Male     33     12     37
#
#    SBA 4  SBA 5  SBA 6  SBAYEAR  unknow  percentage  level  SBA
# 0     10     22     19      142   36.06     45.0750      3   45
# ...

# %%
# last five learners

data.tail()
# Out:
#     No  Unnamed: 1  Acc No             Learner  Gender  SBA 1  SBA 2  SBA 3  \
# 59  60        1351   21014  SESHABELA, Mongezi  Female     35     24     37
# 60  61        1418   21093  SIKAULELA, Lethabo  Female     40     25     36
# 61  62        1425   21082       TOOKA, Kopano    Male     40     15     35
# 62  63        1389   21059  TSATSI, Kelebogile  Female     34     33     36
# 63  64        1345   21008   TSHABALALA, Thero  Female     31     12     40
#
#     SBA 4  SBA 5  SBA 6  SBAYEAR  unknow  percentage  level  SBA
# 59     12     31     23      164   41.65     52.0625      4   52
# 60     13     43      2      163   41.40     51.7500      4   52
# 61     20     39     39      191   48.51     60.6375      5   61
# 62     31     44     24      202   51.30     64.1250      5   64
# 63     15     43     23      165   41.90     52.3750      4   52

# %%
# shape is not a function

data.shape
# Out:
# (64, 16)

# %%
# change the numeric values form categorical to numeric (continuous)

# data['Gender']=labEncod.fit_transform(data['Gender'])

# %%
data.describe()
# Out:
#               No   Unnamed: 1        Acc No      SBA 1      SBA 2      SBA 3  \
# count  64.000000    64.000000     64.000000  64.000000  64.000000  64.000000
# mean   32.500000  1367.875000  20763.281250  35.812500  20.531250  33.875000
# std    18.618987   172.584049   2322.427906   4.174279  10.677032   5.845905
# min     1.000000   170.000000   2983.000000  24.000000   4.000000  18.000000
# 25%    16.750000  1349.750000  21012.750000  34.000000  12.000000  30.750000
# 50%    32.500000  1393.500000  21059.500000  36.000000  20.000000  35.000000
# 75%    48.250000  1422.500000  21086.250000  37.250000  27.000000  38.000000
# max    64.000000  1552.000000  22121.000000  48.000000  50.000000  44.000000
#
#            SBA 4      SBA 5      SBA 6     SBAYEAR     unknow  percentage  \
# count  64.000000  64.000000  64.000000   64.000000  64.000000   64.000000
# mean   17.156250  37.703125  20.937500  168.515625  42.797813   53.497266
# ...

# %%
data.median()
# Out:
# No               32.50
# Unnamed: 1     1393.50
# Acc No        21059.50
# SBA 1            36.00
# SBA 2            20.00
# SBA 3            35.00
# SBA 4            13.00
# SBA 5            39.00
# SBA 6            23.00
# SBAYEAR         163.00
# unknow           41.40
# percentage       51.75
# level             4.00
# SBA              52.00
# dtype: float64

# %%
data.mean()
# Out:
# No               32.500000
# Unnamed: 1     1367.875000
# Acc No        20763.281250
# SBA 1            35.812500
# SBA 2            20.531250
# SBA 3            33.875000
# SBA 4            17.156250
# SBA 5            37.703125
# SBA 6            20.937500
# SBAYEAR         168.515625
# unknow           42.797813
# percentage       53.497266
# level             3.906250
# SBA              53.500000
# dtype: float64

# %%
data.min()
# Out:
# No                      1
# Unnamed: 1            170
# Acc No               2983
# Learner       BAPELA, Joy
# Gender             Female
# SBA 1                  24
# SBA 2                   4
# SBA 3                  18
# SBA 4                   0
# SBA 5                  18
# SBA 6                   1
# SBAYEAR               106
# unknow              26.92
# percentage          33.65
# level                   2
# SBA                    34
# dtype: object

# %%
data.max()
# Out:
# No                           64
# Unnamed: 1                 1552
# Acc No                    22121
# Learner       TSHABALALA, Thero
# Gender                     Male
# SBA 1                        48
# SBA 2                        50
# SBA 3                        44
# SBA 4                        62
# SBA 5                        50
# SBA 6                        49
# SBAYEAR                     286
# unknow                    72.63
# percentage              90.7875
# level                         7
# SBA                          91
# dtype: object

# %%
data.columns
# Out:
# Index(['No', 'Unnamed: 1', 'Acc No', 'Learner', 'Gender', 'SBA 1', 'SBA 2',
#        'SBA 3', 'SBA 4', 'SBA 5', 'SBA 6', 'SBAYEAR', 'unknow', 'percentage',
#        'level', 'SBA'],
#       dtype='object')

# %%
data.Learner.head()
# Out:
# 0           BAPELA, Joy
# 1    BOKABA, Gaboitsiwe
# 2    BOKABA, Kelebogile
# 3       BOKABA, Ofentse
# 4      BOPAPE, Johannah
# Name: Learner, dtype: object

# %%
data[["Learner","level", "percentage"]]
# Out:
#                Learner  level  percentage
# 0          BAPELA, Joy      3     45.0750
# 1   BOKABA, Gaboitsiwe      2     33.6500
# 2   BOKABA, Kelebogile      3     45.0750
# 3      BOKABA, Ofentse      4     54.9250
# 4     BOPAPE, Johannah      5     62.8625
# ..                 ...    ...         ...
# 59  SESHABELA, Mongezi      4     52.0625
# 60  SIKAULELA, Lethabo      4     51.7500
# 61       TOOKA, Kopano      5     60.6375
# 62  TSATSI, Kelebogile      5     64.1250
# 63   TSHABALALA, Thero      4     52.3750
#
# [64 rows x 3 columns]

# %%
# highest mark on assesment 3

data["SBA 3"].max()
# Out:
# 44

# %%
# lowest mark in assesment 3

data["SBA 3"].min()
# Out:
# 18

# %%
# learners who passes based on SBA (year marks except for final marks)

data[data.SBA >= 40]
# Out:
#     No  Unnamed: 1  Acc No                  Learner  Gender  SBA 1  SBA 2  \
# 0    1        1403   21078              BAPELA, Joy  Female     34     13
# 2    3        1411   21074       BOKABA, Kelebogile    Male     37     18
# 3    4        1513   22064          BOKABA, Ofentse  Female     35     23
# 4    5        1343   21006         BOPAPE, Johannah  Female     37     32
# 5    6        1409   21068          KABINI, Boipelo  Female     37     22
# 6    7        1512   22063           KGAFELA, Cathy  Female     41     32
# 7    8        1445   21111          KGAFELA, Khutso    Male     31     12
# 9   10        1348   21011             KOBE, Junior    Male     33     12
# 10  11        1362   21048               KOLA, Paul    Male     37     19
# 11  12        1341   21004            KUTUMELA, Neo    Male     36      8
# 12  13        1427   21090           KWAKWA, Palesa  Female     34     23
# 13  14        1323   20256           KWAKWA, Serame    Male     36     38
# ...

# %%
# learners who did not meet requirements based on SBA (year marks except for final marks)

data[data.SBA < 40]
# Out:
#     No  Unnamed: 1  Acc No                   Learner  Gender  SBA 1  SBA 2  \
# 1    2        1410   21075        BOKABA, Gaboitsiwe  Female     25      7
# 8    9        1447   21112          KGAFELA, Oratile    Male     33     14
# 22  23        1407   21066          MALETE, Johannes    Male     32      9
# 29  30        1551   22120  MASEMENE, Simon Refentse    Male     41      4
# 35  36        1347   21010         MATSEPA, Tshepiso    Male     24     13
# 41  42        1393   21055           MOKGOKO, Tumelo    Male     37      7
#
#     SBA 3  SBA 4  SBA 5  SBA 6  SBAYEAR  unknow  percentage  level  SBA
# 1      27      5     34      6      106   26.92     33.6500      2   34
# 8      25     10     24      6      116   29.46     36.8250      2   37
# 22     35      7     31      3      121   30.73     38.4125      2   38
# 29     28      8     18      4      110   27.94     34.9250      2   35
# 35     32      8     34      5      117   29.71     37.1375      2   37
# ...

# %%
# my top 10 learners for grade 9 2022
# arranged in order of perfomance.

data[data.SBA >= 66].sort_values(by='SBA', ascending=False)
# Out:
#     No  Unnamed: 1  Acc No                Learner  Gender  SBA 1  SBA 2  \
# 40  41        1401   21064     MOEKETSI, Rorisang  Female     40     50
# 30  31        1395   21061  MASETLHA, Mmanthatise  Female     44     41
# 56  57        1429   21083  SEELETSE, Lehlogonolo    Male     37     40
# 55  56        1396   21060      RAMASODI, Keletso  Female     48     36
# 25  26        1338   21001        MALOKA, Omphile  Female     39     40
# 13  14        1323   20256         KWAKWA, Serame    Male     36     38
# 57  58        1412   21073   SEMETSENG, Onthatile    Male     37     37
# 6    7        1512   22063         KGAFELA, Cathy  Female     41     32
# 26  27        1354   21017        MALOKA, Oratile  Female     38     27
# 58  59        1344   21007    SESHABELA, Mitchell  Female     39     25
#
#     SBA 3  SBA 4  SBA 5  SBA 6  SBAYEAR  unknow  percentage  level  SBA
# 40     37     62     50     49      286   72.63     90.7875      7   91
# ...

# %%
# Best learner of 2022 grade 9

data[data.SBA==data.SBA.max()]
# Out:
#     No  Unnamed: 1  Acc No             Learner  Gender  SBA 1  SBA 2  SBA 3  \
# 40  41        1401   21064  MOEKETSI, Rorisang  Female     40     50     37
#
#     SBA 4  SBA 5  SBA 6  SBAYEAR  unknow  percentage  level  SBA
# 40     62     50     49      286   72.63     90.7875      7   91

# %%
# Name of my learner

data['Learner'][data.SBA==data.SBA.max()]
# Out:
# 40    MOEKETSI, Rorisang
# Name: Learner, dtype: object

# %%
data[['Learner', 'SBA']][data.SBA==data.SBA.max()]
# Out:
#                Learner  SBA
# 40  MOEKETSI, Rorisang   91

# %%
# sorting the learners lowest to highest
# the ouput shows the head and tail of the data.

data.sort_values(by=['SBA'])
# Out:
#     No  Unnamed: 1  Acc No                   Learner  Gender  SBA 1  SBA 2  \
# 1    2        1410   21075        BOKABA, Gaboitsiwe  Female     25      7
# 41  42        1393   21055           MOKGOKO, Tumelo    Male     37      7
# 29  30        1551   22120  MASEMENE, Simon Refentse    Male     41      4
# 8    9        1447   21112          KGAFELA, Oratile    Male     33     14
# 35  36        1347   21010         MATSEPA, Tshepiso    Male     24     13
# ..  ..         ...     ...                       ...     ...    ...    ...
# 25  26        1338   21001           MALOKA, Omphile  Female     39     40
# 55  56        1396   21060         RAMASODI, Keletso  Female     48     36
# 56  57        1429   21083     SEELETSE, Lehlogonolo    Male     37     40
# 30  31        1395   21061     MASETLHA, Mmanthatise  Female     44     41
# 40  41        1401   21064        MOEKETSI, Rorisang  Female     40     50
#
# ...

# %%
# sorting the learners highest to lowest

data.sort_values(by='SBA', ascending=False)
# Out:
#     No  Unnamed: 1  Acc No                   Learner  Gender  SBA 1  SBA 2  \
# 40  41        1401   21064        MOEKETSI, Rorisang  Female     40     50
# 30  31        1395   21061     MASETLHA, Mmanthatise  Female     44     41
# 56  57        1429   21083     SEELETSE, Lehlogonolo    Male     37     40
# 55  56        1396   21060         RAMASODI, Keletso  Female     48     36
# 25  26        1338   21001           MALOKA, Omphile  Female     39     40
# ..  ..         ...     ...                       ...     ...    ...    ...
# 8    9        1447   21112          KGAFELA, Oratile    Male     33     14
# 35  36        1347   21010         MATSEPA, Tshepiso    Male     24     13
# 29  30        1551   22120  MASEMENE, Simon Refentse    Male     41      4
# 41  42        1393   21055           MOKGOKO, Tumelo    Male     37      7
# 1    2        1410   21075        BOKABA, Gaboitsiwe  Female     25      7
#
# ...
